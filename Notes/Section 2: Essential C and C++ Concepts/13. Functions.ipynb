# %% [markdown]
# # What are functions?
# **Ans:** Function is a groupe code that executes related tasks.
#
# Instead of having a monoluthic code, where we have all operations of the program under the main body, we will break down to modules so as to make the code easy to understand as well as to find bugs. This breakdown program is known as modular or procedural programming.
#
# ```c
# int main(){
#     ----
#     ----
#     ----
#     ----
#     ----
#     ----
#     ----
#     ----
#     ----
# }
#
# TO
#
# datatype func_1(){
#     ----
#     ----
# }
#
# datatype func_2(){
#     ----
#     ----
#     ----
# }
# .
# .
# .
# datatype func_n(){
#     ----
#     ----
#     ----
# }
#
#
# int main(){
#     ----
#     func_1()
#     func_2()
#     .
#     .
#     .
#     func_n()
# }
#
# ```
#
# For example,
#
# ```c
# int add(int a, int b){
#     int c;
#     c = a + b;
#     return(c);
# }
#
# int main(){
#     int x,y,z;
#     x = 10;
#     y = 5;
#     z = add(x, y);
#     printf("Sum of %d and %d is %d", x, y, z);
# }
# ```
# <br>

# %% [markdown]
# # What is Parameter? Name the types.
# **Ans:**
